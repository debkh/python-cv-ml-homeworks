# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, Input, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, BatchNormalization, RandomTranslation, RandomZoom, Rescaling
from tensorflow.keras import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from time import time

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# Set the seeds for reproducibility
from numpy.random import seed
from tensorflow.random import set_seed
seed_value = 1234578790
seed(seed_value)
set_seed(seed_value)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Dataset params
num_classes = 10
size = x_train.shape[1]

print('Train set:   ', len(y_train), 'samples')
print('Test set:    ', len(y_test), 'samples')
print('Sample dims: ', x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train set:    60000 samples
# Test set:     10000 samples
# Sample dims:  (60000, 28, 28)

# %%
cnt = 1
for r in range(3):
    for c in range(6):
        idx = np.random.randint(len(x_train))
        plt.subplot(3,6,cnt)
        plt.imshow(x_train[idx, ...], cmap='gray')
        plt.title(y_train[idx])
        cnt = cnt + 1

# %%
# Data normalization + add channel dimension (28,28) -> (28,28,1)
x_train = x_train.astype('float32')[..., None] / 255.0
x_test = x_test.astype('float32')[..., None] / 255.0

print('x_train shape:', x_train.shape, 'min:', x_train.min(), 'max:', x_train.max())

# %%
inputs = Input(shape=(28, 28, 1))
net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(inputs)
net = Flatten()(net)
net = Dense(128)(net)
outputs = Dense(10, activation="softmax")(net)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     3,211,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,213,002 (12.26 MB)
#  Trainable params: 3,213,002 (12.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 64

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0991 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0983 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0981 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0974 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0973 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.0972 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0974 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0981 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0974 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0978 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0976 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0980 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0974 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.0977 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3029

# %%
def plot_history(history):
    h = history.history
    epochs = range(len(h['loss']))

    plt.subplot(121), plt.plot(epochs, h['loss'], '.-', epochs, h['val_loss'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('loss')
    plt.legend(['Train', 'Validation'])
    plt.subplot(122), plt.plot(epochs, h['accuracy'], '.-',
                               epochs, h['val_accuracy'], '.-')
    plt.grid(True), plt.xlabel('epochs'), plt.ylabel('Accuracy')
    plt.legend(['Train', 'Validation'])
        
    print('Train Acc     ', h['accuracy'][-1])
    print('Validation Acc', h['val_accuracy'][-1])
    
plot_history(history)
# Out:
# Train Acc      0.0976666659116745
# Validation Acc 0.10000000149011612

# %%
# Modified network architecture to get rid of overfitting

data_augmentation = Sequential([
    RandomTranslation(0.05, 0.05),
    RandomZoom(0.05),
])

modified_inputs = Input(shape=(28, 28, 1))
net = data_augmentation(modified_inputs)

net = Conv2D(32, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)

net = Conv2D(64, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = MaxPooling2D(pool_size=(2, 2))(net)

net = Conv2D(128, kernel_size=(3, 3), activation="relu", padding='same')(net)
net = BatchNormalization()(net)
net = AveragePooling2D(pool_size=(2, 2))(net)
net = Dropout(0.3)(net)

net = GlobalAveragePooling2D()(net)
net = Dense(128, activation="relu")(net)
net = Dropout(0.3)(net)

modified_outputs = Dense(10, activation="softmax")(net)

modified_model = Model(modified_inputs, modified_outputs)
modified_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 7, 7, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 7, 7, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_2             │ (None, 3, 3, 128)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,370 (435.04 KB)
#  Trainable params: 110,922 (433.29 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
epochs = 50
batch_size = 64

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=5,
        restore_best_weights=True
    ),
    ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2
    )
]

modified_model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
modified_history = modified_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.0958 - loss: 2.3043 - val_accuracy: 0.1000 - val_loss: 4.2625
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0995 - loss: 2.3032 - val_accuracy: 0.1000 - val_loss: 2.9078
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0987 - loss: 2.3032 - val_accuracy: 0.1000 - val_loss: 2.8497
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0995 - loss: 2.3032 - val_accuracy: 0.1000 - val_loss: 9.1090
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0985 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 4.6337
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.0971 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 20.0196
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 8.2129
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.0979 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3251
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0982 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 5.0394
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0981 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0975 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3087
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0968 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 2.5008
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0978 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0980 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3050
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0980 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.4304
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.0982 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0980 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026

# %%
plot_history(modified_history)
# Out:
# Train Acc      0.09794999659061432
# Validation Acc 0.10000000149011612
